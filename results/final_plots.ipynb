# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
from plot import *
from plot_utils import *

# %%
infar = ['infar'+os.sep+f for f in os.listdir('infar') if os.path.isfile('infar'+os.sep+f) and not f.endswith(('.json', '.py', '.ipynb'))]
infar_prefix = '%s_'%('infar'+os.sep+'infar')
infar.sort()
ucfsports = ['ucfsports'+os.sep+f for f in os.listdir('ucfsports') if os.path.isfile('ucfsports'+os.sep+f) and not f.endswith(('.json', '.py', '.ipynb'))]
ucfsports_prefix = '%s_'%('ucfsports'+os.sep+'ucfsports')
ucfsports.sort()
ucf11 = ['ucf11'+os.sep+f for f in os.listdir('ucf11') if os.path.isfile('ucf11'+os.sep+f) and not f.endswith(('.json', '.py', '.ipynb'))]
ucf11_prefix = '%s_'%('ucf11'+os.sep+'ucf11')
ucf11.sort()
jhmdb = ['jhmdb'+os.sep+f for f in os.listdir('jhmdb') if os.path.isfile('jhmdb'+os.sep+f) and not f.endswith(('.json', '.py', '.ipynb'))]
jhmdb.sort()
kth = ['kth'+os.sep+f for f in os.listdir('kth') if os.path.isfile('kth'+os.sep+f) and not f.endswith(('.json', '.py', '.ipynb'))]
kth_prefix = '%s_'%('kth'+os.sep+'kth')
kth.sort()

# %%
labels = None
horizontal = True
subplots = 140 if horizontal else 220

f = plt.figure(figsize=(20,16))
if horizontal: f = plt.figure(figsize=(40,8))


prefix2 = (kth_prefix+'2_BBB', kth_prefix+'2_resnet18')
ax = ipypthon_plot_log(kth, prefix=prefix2, suffix=('_val.log', '_train.log'), col=('acc_mean', 'acc'),
                  subplot=subplots+1 ,figure=f,
                  labels=['Bayesian ResNet-18 Training', 'Bayesian ResNet-18 Validation', 
                          #'Dropout ResNet-18 Training', 'Dropout ResNet-18 Validation',
                          'Frequentist ResNet-18 Training', 'Frequentist ResNet-18 Validation'] if labels else None,
                  linestyles=[':', '-', ':', '-', ':', '-'],
                  colors=[blue, blue, orange, orange],#[blue, blue, green, green, orange, orange],
                  legend_fontsize=15,
                  xlim=(-5, 161), ylim=(0, 100), yticks=range(0,101,10))
ax.set_ylabel('Accuracy', fontsize=14, alpha=0.75)
ax.set_xlabel('Epochs', labelpad=15, fontsize=14, alpha=0.75)
ax.set_title('KTH', fontsize=18)

prefix2 = (ucfsports_prefix+'2_BBB', ucfsports_prefix+'2_resnet18')
ax = ipypthon_plot_log(ucfsports, prefix=prefix2, suffix=('_val.log', '_train.log'), col=('acc_mean', 'acc'),
                  subplot=subplots+2 ,figure=f,
                  labels=['Bayesian ResNet-18 Training', 'Bayesian ResNet-18 Validation', 
                          #'Dropout ResNet-18 Training', 'Dropout ResNet-18 Validation',
                          'Frequentist ResNet-18 Training', 'Frequentist ResNet-18 Validation'] if labels else None,
                  linestyles=[':', '-', ':', '-', ':', '-'],
                  colors=[blue, blue, orange, orange, green, green],
                  legend_fontsize=15,
                  xlim=(-15,280), ylim=(0,100), yticks=range(0,101,10))
ax.set_ylabel('Accuracy', fontsize=14, alpha=0.75)
ax.set_xlabel('Epochs', labelpad=15, fontsize=14, alpha=0.75)
ax.set_title('UCF Sports', fontsize=18)

prefix3 = (ucf11_prefix+'3_resnet18', ucf11_prefix+'3_BBB')#, ucf11_prefix+'3_dropout_resnet18_ot2')
ax = ipypthon_plot_log(ucf11, prefix=prefix3, suffix=('_val.log', '_train.log'), col=('acc_mean', 'acc'),
                  subplot=subplots+3 ,figure=f,
                  labels=['Bayesian ResNet-18 Training', 'Bayesian ResNet-18 Validation', 
                          #'Dropout ResNet-18 Training', 'Dropout ResNet-18 Validation',
                          'Frequentist ResNet-18 Training', 'Frequentist ResNet-18 Validation'] if labels else None,
                  linestyles=[':', '-', ':', '-', ':', '-'],
                  colors=[blue, blue, orange, orange],#[blue, blue, green, green, orange, orange],
                  legend_fontsize=15,
                  xlim=(-5, 170), ylim=(0, 100), yticks=range(0,101,10))
ax.set_ylabel('Accuracy', fontsize=14, alpha=0.75)
ax.set_xlabel('Epochs', labelpad=15, fontsize=14, alpha=0.75)
ax.set_title('UCF11', fontsize=18)

infar_prefix1 = (infar_prefix+'BBB', infar_prefix+'res')
ax = ipypthon_plot_log(infar, prefix=infar_prefix1, suffix=('_val.log', '_train.log'), col=('acc_mean', 'acc'),
                  subplot=subplots+4, figure=f,
                  labels=['Bayesian ResNet-18 Training', 'Bayesian ResNet-18 Validation', 
                          #'Dropout ResNet-18 Training', 'Dropout ResNet-18 Validation',
                          'Frequentist ResNet-18 Training', 'Frequentist ResNet-18 Validation'] if labels else None,
                  linestyles=[':', '-', ':', '-', ':', '-'],
                  colors=[blue, blue, orange, orange],#[blue, blue, green, green, orange, orange],
                  legend_fontsize=14,
                  xlim=(-15,200), ylim=(0,102), yticks=range(0,101,10))
ax.set_ylabel('Accuracy', fontsize=14, alpha=0.75)
ax.set_xlabel('Epochs', labelpad=15, fontsize=14, alpha=0.75)
ax.set_title('infAR', fontsize=18)

plt.tight_layout(h_pad=5, w_pad=5)
plt.show()

# %%
labels = None
vertical = None

f = plt.figure(figsize=(33,8.5))# 3 -> 33,8.5 #2 -> 30,11
if vertical: f = plt.figure(figsize=(11,30))#2 -> 10,18

subplots = 310 if vertical else 130

prefix2 = kth_prefix+'2_'
ax = ipypthon_plot_log(kth, prefix=prefix2, suffix=('_val.log', '_train.log'), col=('acc_mean', 'acc'),
                  subplot=subplots+1, figure=f,
                  labels=['Bayesian ResNet-18 Training', 'Bayesian ResNet-18 Validation', 
                          'Dropout ResNet-18 Training', 'Dropout ResNet-18 Validation',
                          'Frequentist ResNet-18 Training', 'Frequentist ResNet-18 Validation'] if labels else None,
                  linestyles=[':', '-', ':', '-', ':', '-'],
                  colors=[blue, blue, green, green, orange, orange],
                  xlim=(-5, 161), ylim=(0, 100), yticks=range(0,101,10))
ax.set_ylabel('Accuracy', fontsize=14, alpha=0.75)
ax.set_xlabel('Epochs', labelpad=15, fontsize=14, alpha=0.75)

prefix3 = (ucf11_prefix+'3_resnet18', ucf11_prefix+'3_BBB', ucf11_prefix+'3_dropout_resnet18_ot2')
ax = ipypthon_plot_log(ucf11, prefix=prefix3, suffix=('_val.log', '_train.log'), col=('acc_mean', 'acc'),
                  subplot=subplots+2 ,figure=f,
                  labels=['Bayesian ResNet-18 Training', 'Bayesian ResNet-18 Validation', 
                          'Dropout ResNet-18 Training', 'Dropout ResNet-18 Validation',
                          'Frequentist ResNet-18 Training', 'Frequentist ResNet-18 Validation'] if labels else None,
                  linestyles=[':', '-', ':', '-', ':', '-'],
                  colors=[blue, blue, green, green, orange, orange],
                  legend_fontsize=14,
                  xlim=(-5, 170), ylim=(0, 100), yticks=range(0,101,10))
ax.set_ylabel('Accuracy', fontsize=14, alpha=0.75)
ax.set_xlabel('Epochs', labelpad=15, fontsize=14, alpha=0.75)
ax.set_title('UCF11', fontsize=18)

infar_prefix1 = (infar_prefix+'BBB', infar_prefix+'res', infar_prefix+'drop')
ax = ipypthon_plot_log(infar, prefix=infar_prefix1, suffix=('_val.log', '_train.log'),
                  subplot=subplots+3 ,col=('acc_mean', 'acc'), figure=f,
                  labels=['Bayesian ResNet-18 Training', 'Bayesian ResNet-18 Validation', 
                          'Dropout ResNet-18 Training', 'Dropout ResNet-18 Validation',
                          'Frequentist ResNet-18 Training', 'Frequentist ResNet-18 Validation'] if labels else None,
                  linestyles=[':', '-', ':', '-', ':', '-'],
                  colors=[blue, blue, green, green, orange, orange],
                  legend_fontsize=14,
                  xlim=(-15,200), ylim=(0,102), yticks=range(0,101,10))
ax.set_ylabel('Accuracy', fontsize=14, alpha=0.75)
ax.set_xlabel('Epochs', labelpad=15, fontsize=14, alpha=0.75)
ax.set_title('infAR', fontsize=18)

#plt.tight_layout()
plt.show()

# %%
labels = None
f = plt.figure(figsize=(30,11))

prefix4 = (kth_prefix+'4_BBB', kth_prefix+'4_drop')
ax = ipypthon_plot_log(kth, prefix=prefix4, suffix=('oth_val.log', 'oth_train.log'), col=('acc_mean', 'acc'), subplot=121 ,figure=f,
                  labels=['Bayesian ResNet-18 Training', 'Bayesian ResNet-18 Validation', 
                  #        'Dropout ResNet-18 Training', 'Dropout ResNet-18 Validation',
                          'Frequentist ResNet-18 Training', 'Frequentist ResNet-18 Validation'] if labels else None,
                  linestyles=[':', '-', ':', '-', ':', '-'],
                  colors=[blue, blue, orange, orange],#green, green, orange, orange],
                  legend_fontsize=14,
                  xlim=(-5, 248), ylim=(0, 100), yticks=range(0,101,10))
ax.set_ylabel('Accuracy', fontsize=14, alpha=0.75)
ax.set_xlabel('Epochs', labelpad=15, fontsize=14, alpha=0.75)
ax.set_title('KTH', fontsize=18)


prefix4=infar_prefix+'4_'
ax = ipypthon_plot_log(infar, prefix=prefix4, suffix=('oth_val.log', 'oth_train.log', '18_val.log', '18_train.log'),
                       col=('acc_mean', 'acc'), subplot=122, figure=f,
                  labels=['Bayesian ResNet-18 Training', 'Bayesian ResNet-18 Validation', 
                          'Dropout ResNet-18 Training', 'Dropout ResNet-18 Validation',
                          'Frequentist ResNet-18 Training', 'Frequentist ResNet-18 Validation'] if labels else None,
                  linestyles=[':', '-', ':', '-', ':', '-'],
                  colors=[blue, blue, green, green, orange, orange],
                  legend=True, legend_fontsize=14, legend_loc=2,
                  xlim=(-15,204), ylim=(0,102), yticks=range(0,101,10))
ax.set_ylabel('Accuracy', fontsize=14, alpha=0.75)
ax.set_xlabel('Epochs', labelpad=15, fontsize=14, alpha=0.75)
ax.set_title('infAR', fontsize=18)

#plt.tight_layout()
plt.show()
