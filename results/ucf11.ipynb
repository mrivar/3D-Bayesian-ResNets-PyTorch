# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
from plot import *
from plot_utils import *

# %%
dataset = 'ucf11'
prefix = '%s_'%(dataset+os.sep+dataset)
logs = [dataset+os.sep+f for f in os.listdir(dataset) if os.path.isfile(dataset+os.sep+f) and not f.endswith(('.json', '.py', '.ipynb'))]
logs.sort()
logs
# Out:
# ['ucf11/ucf11_3_BBBresnet18_q-5_train.log',
#  'ucf11/ucf11_3_BBBresnet18_q-5_train_batch.log',
#  'ucf11/ucf11_3_BBBresnet18_q-5_uncertainty.log',
#  'ucf11/ucf11_3_BBBresnet18_q-5_val.log',
#  'ucf11/ucf11_3_dropout_resnet18_ot2_train.log',
#  'ucf11/ucf11_3_dropout_resnet18_ot2_train_batch.log',
#  'ucf11/ucf11_3_dropout_resnet18_ot2_uncertainty.log',
#  'ucf11/ucf11_3_dropout_resnet18_ot2_val.log',
#  'ucf11/ucf11_3_dropout_resnet18_oth_train.log',
#  'ucf11/ucf11_3_dropout_resnet18_oth_train_batch.log',
#  'ucf11/ucf11_3_dropout_resnet18_oth_uncertainty.log',
#  'ucf11/ucf11_3_dropout_resnet18_oth_val.log',
#  'ucf11/ucf11_3_dropout_resnet18_train.log',
#  'ucf11/ucf11_3_dropout_resnet18_train_batch.log',
#  'ucf11/ucf11_3_dropout_resnet18_uncertainty.log',
#  'ucf11/ucf11_3_dropout_resnet18_val.log',
#  'ucf11/ucf11_3_resnet18_train.log',
#  'ucf11/ucf11_3_resnet18_train_batch.log',
#  'ucf11/ucf11_3_resnet18_uncertainty.log',
#  'ucf11/ucf11_3_resnet18_val.log',
#  'ucf11/ucf11_4_resnet18_train.log',
#  'ucf11/ucf11_4_resnet18_train_batch.log',
#  'ucf11/ucf11_4_resnet18_uncertainty.log',
#  'ucf11/ucf11_4_resnet18_val.log',
#  'ucf11/ucf11_resnet18_train.log',
#  'ucf11/ucf11_resnet18_train_batch.log',
#  'ucf11/ucf11_resnet18_uncertainty.log',
#  'ucf11/ucf11_resnet18_val.log']

# %%
#prefix3 = (prefix+'3_resnet18', prefix+'3_BBB', prefix+'3_dropout_resnet18_val', prefix+'3_dropout_resnet18_tra')
#prefix3 = (prefix+'3_resnet18', prefix+'3_BBB', prefix+'3_dropout_resnet18_oth')
prefix3 = (prefix+'3_resnet18', prefix+'3_BBB', prefix+'3_dropout_resnet18_ot2')
f = plt.figure(figsize=(10.5,7.8))
ax = ipypthon_plot_log(logs, prefix=prefix3, suffix=('_val.log', '_train.log'), col=('acc_mean', 'acc'), figure=f,
                  labels=['Bayesian ResNet-18 Training', 'Bayesian ResNet-18 Validation', 
                          'Dropout ResNet-18 Training', 'Dropout ResNet-18 Validation',
                          'Frequentist ResNet-18 Training', 'Frequentist ResNet-18 Validation'],
                  linestyles=[':', '-', ':', '-', ':', '-'],
                  colors=[blue, blue, green, green, orange, orange],
                  legend_formatting=True,
                  xlim=(-5, 170), ylim=(0, 100), yticks=range(0,101,10))
ax.set_ylabel('Accuracy', fontsize=14, alpha=0.75)
ax.set_xlabel('Epochs', labelpad=15, fontsize=14, alpha=0.75)
plt.show()

# %%
prefix3 = prefix+'3_'
f = plt.figure(figsize=(20,5))
ipypthon_plot_log(logs, prefix=prefix3, suffix='_val.log', col='acc_mean', subplot=131, figure=f, xlim=(-15, 400), ylim=(0, 100), yticks=range(0,101,10))
ipypthon_plot_log(logs, prefix=prefix3, suffix='_train.log', col='acc', subplot=132, figure=f, xlim=(-15, 300), ylim=(0, 100), yticks=range(0,101,10))
ipypthon_plot_log(logs, prefix=prefix3, suffix='_train.log', col='lr', subplot=133, figure=f)
plt.show()

# %% [markdown]
# ### Split 3 (Separated by video style (ucf11 subfolders))

# %%
f = plt.figure(figsize=(20,5))
ipypthon_plot_log(logs, prefix=prefix, suffix='_train.log', col='acc', subplot=131, figure=f)
ipypthon_plot_log(logs, prefix=prefix, suffix='_train.log', col='acc', subplot=132, figure=f)
ipypthon_plot_log(logs, prefix=prefix, suffix='_train.log', col='acc', subplot=133, figure=f)
plt.show()

# %% [markdown]
# ### Split 1 (Uniformly separated)

# %%
prefix1 = (prefix+'r', prefix+'B')
f = plt.figure(figsize=(20,5))
ipypthon_plot_log(logs, prefix=prefix1, suffix='_val.log', col='acc_mean', subplot=131, figure=f, xlim=(-10, 300), ylim=(0, 100), yticks=range(0,101,10))
ipypthon_plot_log(logs, prefix=prefix1, suffix='_train.log', col='acc', subplot=132, figure=f)
ipypthon_plot_log(logs, prefix=prefix1, suffix='_train.log', col='lr', subplot=133, figure=f)
plt.show()

# %%
f = plt.figure(figsize=(20,5))
ipypthon_plot_log(logs, prefix=prefix, suffix='_val.log', col='loss', subplot=131, figure=f)
ipypthon_plot_log(logs, prefix=prefix, suffix='_val.log', col='loss', subplot=132, figure=f)
ipypthon_plot_log(logs, prefix=prefix, suffix='_val.log', col='loss', subplot=133, figure=f)
plt.show()

# %%
f = plt.figure(figsize=(20,5))
ipypthon_plot_log(logs, prefix=prefix, suffix='_train.log', col='lr', subplot=131, figure=f)
ipypthon_plot_log(logs, prefix=prefix, suffix='_train.log', col='lr', subplot=132, figure=f)
ipypthon_plot_log(logs, prefix=prefix, suffix='_train.log', col='lr', subplot=133, figure=f)
plt.show()
