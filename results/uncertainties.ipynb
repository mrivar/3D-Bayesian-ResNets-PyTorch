# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
from plot import *
from plot_utils import *

# %%
infar = ['infar'+os.sep+f for f in os.listdir('infar') if os.path.isfile('infar'+os.sep+f) and not f.endswith(('.json', '.py', '.ipynb'))]
infar.sort()
ucfsports = ['ucfsports'+os.sep+f for f in os.listdir('ucfsports') if os.path.isfile('ucfsports'+os.sep+f) and not f.endswith(('.json', '.py', '.ipynb'))]
ucfsports.sort()
ucf11 = ['ucf11'+os.sep+f for f in os.listdir('ucf11') if os.path.isfile('ucf11'+os.sep+f) and not f.endswith(('.json', '.py', '.ipynb'))]
ucf11.sort()
jhmdb = ['jhmdb'+os.sep+f for f in os.listdir('jhmdb') if os.path.isfile('jhmdb'+os.sep+f) and not f.endswith(('.json', '.py', '.ipynb'))]
jhmdb.sort()
kth = ['kth'+os.sep+f for f in os.listdir('kth') if os.path.isfile('kth'+os.sep+f) and not f.endswith(('.json', '.py', '.ipynb'))]
kth.sort()

# %%
get_avg_uncertainty_values(infar, ('infar_BBBresnet18_q-5_uncertainty',), midstring='\t\t')
get_avg_uncertainty_values(ucfsports, ('ucfsports_2_BBBresnet18_q-5_uncertainty',), midstring='\t')
get_avg_uncertainty_values(ucf11, ('ucf11_3_BBBresnet18_q-5_uncertainty',), midstring='\t\t')
get_avg_uncertainty_values(kth, ('kth_2_BBBresnet18_q-5_uncertainty',), midstring='\t\t')
print('----------------------------')
get_last_uncertainty_values(infar, ('infar_BBBresnet18_q-5_uncertainty',), midstring='\t\t', loc=76)
get_last_uncertainty_values(ucfsports, ('ucfsports_2_BBBresnet18_q-5_uncertainty',), midstring='\t', loc=252)
get_last_uncertainty_values(ucf11, ('ucf11_3_BBBresnet18_q-5_uncertainty',), midstring='\t\t', loc=156)
get_last_uncertainty_values(kth, ('kth_2_BBBresnet18_q-5_uncertainty',), midstring='\t\t', loc=107)
# Out:
# infar/infar_BBBresnet18_q-5_uncertainty.log: 		Epistemic: 0.036499	Aleatoric: 0.112398
# ucfsports/ucfsports_2_BBBresnet18_q-5_uncertainty.log: 	Epistemic: 0.046729	Aleatoric: 0.144067
# ucf11/ucf11_3_BBBresnet18_q-5_uncertainty.log: 		Epistemic: 0.039646	Aleatoric: 0.167853
# kth/kth_2_BBBresnet18_q-5_uncertainty.log: 		Epistemic: 0.036550	Aleatoric: 0.155751
# ----------------------------
# infar/infar_BBBresnet18_q-5_uncertainty.log: 		Epistemic: 0.005244	Aleatoric: 0.087878
# ucfsports/ucfsports_2_BBBresnet18_q-5_uncertainty.log: 	Epistemic: 0.016325	Aleatoric: 0.107257
# ucf11/ucf11_3_BBBresnet18_q-5_uncertainty.log: 		Epistemic: 0.042903	Aleatoric: 0.111200
# kth/kth_2_BBBresnet18_q-5_uncertainty.log: 		Epistemic: 0.035450	Aleatoric: 0.124120

# %% [markdown]
# # Epistemic (Model based)

# %%
f = plt.figure(figsize=(20,10))
ipypthon_plot_unc(ucfsports, prefix='ucfsports/ucfsports_2', suffix='q-5_uncertainty.log', subplot=231, figure=f, marker_epoch=163, title="UCF Sports 1")
ipypthon_plot_unc(ucfsports, prefix='ucfsports/ucfsports_B', suffix='oth_uncertainty.log', subplot=232, figure=f, marker_epoch=181, title="UCF Sports 2")
ipypthon_plot_unc(ucfsports, prefix='ucfsports/ucfsports_B', suffix='q-5_uncertainty.log', subplot=233, figure=f, marker_epoch=95, title="UCF Sports 3")
ipypthon_plot_unc(infar, prefix='infar/infar_', suffix='q-5_uncertainty.log', subplot=234, figure=f, marker_epoch=76, title="InfAR")
ipypthon_plot_unc(ucf11, prefix='ucf11/ucf11_3', suffix='q-5_uncertainty.log', subplot=235, figure=f, marker_epoch=77, title="UCF11")
ipypthon_plot_unc(jhmdb, prefix='jhmdb/jhmdb_', suffix='q-5_uncertainty.log', subplot=236, figure=f, marker_epoch=30, title="JHMDB")
#f.text(0.05, 0.8, 'CIFAR-100', fontsize=15, fontweight='semibold', rotation=45)
#f.text(0.05, 0.52, 'CIFAR-10', fontsize=15, fontweight='semibold', rotation=45)
#f.text(0.05, 0.25, 'MNIST', fontsize=15, fontweight='semibold', rotation=45)
#f.text(0.21, 0.05, 'ALL DATA', fontsize=15, fontweight='semibold')
#f.text(0.505, 0.05, '1/4', fontsize=15, fontweight='semibold')
#f.text(0.775, 0.05, '1/32', fontsize=15, fontweight='semibold')
plt.show()

# %% [markdown]
# # Aleatoric (Data based)

# %%
f = plt.figure(figsize=(20,10))
ipypthon_plot_unc(ucfsports, prefix='ucfsports/ucfsports_2', suffix='q-5_uncertainty.log', subplot=231, figure=f, what_unc="aleatoric", marker_epoch=163, title="UCF Sports 1")
ipypthon_plot_unc(ucfsports, prefix='ucfsports/ucfsports_B', suffix='oth_uncertainty.log', subplot=232, figure=f, what_unc="aleatoric", marker_epoch=181, title="UCF Sports 2")
ipypthon_plot_unc(ucfsports, prefix='ucfsports/ucfsports_B', suffix='q-5_uncertainty.log', subplot=233, figure=f, what_unc="aleatoric", marker_epoch=95, title="UCF Sports 3")
ipypthon_plot_unc(infar, prefix='infar/infar_', suffix='q-5_uncertainty.log', subplot=234, figure=f, what_unc="aleatoric", marker_epoch=76, title="InfAR")
ipypthon_plot_unc(ucf11, prefix='ucf11/ucf11_3', suffix='q-5_uncertainty.log', subplot=235, figure=f, what_unc="aleatoric", marker_epoch=77, title="UCF11")
ipypthon_plot_unc(jhmdb, prefix='jhmdb/jhmdb_', suffix='q-5_uncertainty.log', subplot=236, figure=f, what_unc="aleatoric", marker_epoch=30, title="JHMDB")
#f.text(0.05, 0.8, 'CIFAR-100', fontsize=15, fontweight='semibold', rotation=45)
#f.text(0.05, 0.52, 'CIFAR-10', fontsize=15, fontweight='semibold', rotation=45)
#f.text(0.05, 0.25, 'MNIST', fontsize=15, fontweight='semibold', rotation=45)
#f.text(0.21, 0.05, 'ALL DATA', fontsize=15, fontweight='semibold')
#f.text(0.505, 0.05, '1/4', fontsize=15, fontweight='semibold')
#f.text(0.775, 0.05, '1/32', fontsize=15, fontweight='semibold')
plt.show()
